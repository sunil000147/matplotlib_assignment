# %%
import  numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
#  ''' ans. Matplotlib is a data visualization library for Python that allows users to create a wide range of static, animated, and interactive visualizations in Python. It provides a range of tools for constructing plots, graphs, and other visual representations of data.
#
# Matplotlib is used for a variety of purposes, including:
#
# Data exploration and analysis: Matplotlib provides a way to quickly visualize data and explore relationships and patterns within it.
#
# Presentation of data: Matplotlib provides a way to create high-quality, publication-ready figures for use in scientific papers, reports, and presentations.
#
# Communication of results: Matplotlib provides a way to create engaging visualizations that communicate data-driven insights to non-technical audiences.
#
# Teaching and learning: Matplotlib provides a way to illustrate and explain key concepts in data visualization and data analysis.
#
# Integration with other libraries: Matplotlib can be easily integrated with other Python libraries such as NumPy, Pandas, and SciPy.
#
# Five plots that can be plotted using the Pyplot module of Matplotlib include:
#
# 1.Line plot
# 2.Scatter plot
# 3.Bar plot
# 4.Histogram
# 5.Box plot '''

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is a type of plot that displays values for two variables as a collection of points on a two-dimensional plane, where each point represents an observation in the dataset. Scatter plots are useful for identifying patterns, trends, and relationships between two variables.

# %%
# Create the data for the scatter plot
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create the figure and axis object
fig, ax = plt.subplots()

# Create the scatter plot
ax.scatter(x, y)

# Add labels and title
ax.set_xlabel('X values')
ax.set_ylabel('Y values')
ax.set_title('Scatter Plot Example')

# Show the plot
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# ans. The subplot() function in Matplotlib is used to create multiple plots in a single figure. It allows us to divide the figure into a grid of rows and columns and specify the location of each plot in the grid.

# %%
# Create the data for the line plots
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create the figure and axis objects
fig, axs = plt.subplots(2, 2)

# Create the line plots
axs[0, 0].plot(x1, y1)
axs[0, 1].plot(x2, y2)
axs[1, 0].plot(x3, y3)
axs[1, 1].plot(x4, y4)

# Add titles and labels to the plots
axs[0, 0].set_title('Line Plot 1')
axs[0, 1].set_title('Line Plot 2')
axs[1, 0].set_title('Line Plot 3')
axs[1, 1].set_title('Line Plot 4')
fig.suptitle('Four Line Plots')

# Adjust the spacing between the plots
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans. A bar plot is a plot that represents categorical data with rectangular bars with lengths proportional to the values that they represent. It is used to compare different categories or groups.
#
# To plot a bar plot and a horizontal bar plot using the given data, we can use the bar() and barh() functions of the pyplot module in Matplotlib.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar Plot
plt.bar(company, profit)
plt.title("Company Profit")
plt.xlabel("Company")
plt.ylabel("Profit (in millions)")
plt.show()

# Horizontal Bar Plot
plt.barh(company, profit)
plt.title("Company Profit")
plt.xlabel("Profit (in millions)")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans.A box plot, also known as a box-and-whisker plot, is a graphical representation of a dataset that shows the distribution of the data based on five number summary - minimum, first quartile (Q1), median, third quartile (Q3), and maximum. It is used to identify the outliers and to compare the distributions of different datasets

# %%
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

# Box Plot
plt.boxplot(data)
plt.title("Box Plot")
plt.xlabel("Data")
plt.ylabel("Values")
plt.show()
